# %% [markdown]
# ## Modules à importer

# %%
import math
import scipy
import pickle
import numpy as np
import pandas as pd
import iminuit as im
import ipywidgets as ipw
from importlib import reload
from scipy.stats import poisson
from scipy.optimize import fsolve
from variaIa.variaIa import baserate
from scipy.interpolate import interp1d
from variaIa.variaIa import stretchevol
from astropy.cosmology import Planck15 as cosmo
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Définitions et sélection de l'échantillon à utiliser

# %%
d = pd.read_csv('../Data/data_cheat.csv', sep=' ', index_col = 'CID')
d_snf = pd.read_csv('../Data/lssfr_paper_full_sntable.csv',sep=',')

surveys = ['SNF', 'SDSS', 'PS1', 'SNLS', 'HST']

su = ipw.Dropdown(options=surveys,
                  description='Survey:',
                  value = 'PS1')

surv = {'SNF':  d_snf,
        'SDSS': d[d['IDSURVEY'] == 1],
        'PS1':  d[d['IDSURVEY'] == 15],
        'SNLS': d[d['IDSURVEY'] == 4],
        'HST':  d[d['IDSURVEY'].isin([101, 100, 106])]}

# .loc[d_snf['name'].str.contains('SNF|LSQ|PTF',na=False,regex=True)]

colors = {'SNF': 'orange',
          'SDSS': 'lime',
          'PS1': 'blue',
          'SNLS': 'red',
          'HST': 'purple'}

def set_data(su):
    global ns_dataz, dataz, ns_datax, datax
    if su == 'SNF':
        ns_dataz = surv[su]['host.zcmb'].values
        dataz = np.sort(ns_dataz)
        ns_datax = surv[su]['salt2.X1'].values
        datax = np.sort(ns_datax)
    else:
        ns_dataz = surv[su].zCMB.values
        dataz = np.sort(ns_dataz)
        ns_datax = surv[su].x1.values
        datax = np.sort(ns_datax)
    
int_data = ipw.interactive(set_data, su = su)
display(int_data)
# Out:
# interactive(children=(Dropdown(description='Survey:', index=2, options=('SNF', 'SDSS', 'PS1', 'SNLS', 'HST'), …

# %% [markdown]
# # Détermination des $z_{\text{max}}$ _via_ baserate

# %% [markdown]
# ## Calcul pour l'échantillon choisi

# %%
reload(baserate)

itsc = .5
guess = .2
loops = 100

res_one = {su.value: baserate.zmax_poisson(su.value, dataz, guess, loops, itsc)}
# Out:
# 10000

# %% [markdown]
# ## Tracé pour l'échantillon choisi

# %%
reload(baserate)

z_lin = {su.value: res_one[su.value][0]}
med = {su.value: res_one[su.value][1]}
std = {su.value: res_one[su.value][2]}
maxx = {su.value: res_one[su.value][3]}

baserate.zmax_pshow(z_lin, med, std, maxx, itsc, True, False)

# %% [markdown]
# ## Tracé pour l'échantillon choisi depuis données sauvegardées

# %%
reload(baserate)

with open('../Data/zmax_095_t_result', 'rb') as f:
    z_lins, meds, stds, z_max = pickle.load(f)

z_lins_one = {su.value: z_lins[su.value]}
meds_one = {su.value: meds[su.value]}
stds_one = {su.value: stds[su.value]}
z_max_one = {su.value: z_max[su.value]}

itsc = .5

baserate.zmax_pshow(z_lins_one, meds_one, stds_one, z_max_one,
                    itsc, True, True)

fig=plt.gcf()
#fig.savefig('/home/nora/Documents/Thèse/Images/zmax_' + str(su.value) +
#'_095_stds_point.pdf', bbox_inches='tight')

# %% [markdown]
# ## Tracé des trois échantillons

# %% [markdown]
# ### Dictionnaires des z_intp, meds, stds et z_max ± inf/sup

# %%
reload(baserate)

res = dict()
meds = dict()
stds = dict()
z_lins = dict()
z_max = dict()

itsc = .5
guess = .2
loops = 1000

for survey in surveys[1:-1]:
    res[survey] = baserate.zmax_poisson(survey,
                                        np.sort(surv[survey].zCMB.values),
                                        guess, loops, itsc)
    z_lins[survey] = res[survey][0]
    meds[survey] = res[survey][1]
    stds[survey] = res[survey][2]
    z_max[survey] = res[survey][3]

# %% [markdown]
# ### Résultats et sauvegarde

# %%
z_max
# Out:
# {'SDSS': array([0.203 , 0.2043, 0.2055]),
#  'PS1': array([0.2763, 0.284 , 0.29  ]),
#  'SNLS': array([0.6122, 0.6155, 0.619 ])}

# %% [markdown]
# #### Attention en m'écrasant !

# %%
with open('../Data/zmax_095_result', 'wb') as f:
    pickle.dump([z_lins, meds, stds, z_max], f)

# %% [markdown]
# ### Tracé effectif

# %%
reload(baserate)

with open('../Data/zmax_095_result', 'rb') as f:
    z_lins, meds, stds, z_max = pickle.load(f)
    
itsc = .5

baserate.zmax_pshow(z_lins, meds, stds, z_max, itsc, True, True)

fig=plt.gcf()
#fig.savefig('/home/nora/Documents/Thèse/Images/zmax_all_095_stds_point.pdf')

# %%
z_max
# Out:
# {'SDSS': [0.2055, 0.2043, 0.203],
#  'PS1': [0.29, 0.284, 0.2763],
#  'SNLS': [0.619, 0.6155, 0.6122]}
